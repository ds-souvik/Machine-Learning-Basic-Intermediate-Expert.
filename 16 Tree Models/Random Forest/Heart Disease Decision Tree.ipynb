# %% [markdown]
# # `This notebook is strictly just to visualize Decision Trees.`

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Basic reading csv

# %%
df=pd.read_csv('heart_v2.csv')
df.head()
# Out:
#    age  sex   BP  cholestrol  heart disease
# 0   70    1  130         322              1
# 1   67    0  115         564              0
# 2   57    1  124         261              1
# 3   64    1  128         263              0
# 4   74    0  120         269              0

# %%
df['heart disease'].value_counts()
# Out:
# 0    150
# 1    120
# Name: heart disease, dtype: int64

# %% [markdown]
# ### Train test split

# %%
y=df.pop('heart disease')
X=df
print(y.shape)
print(X.shape)
# Out:
# (270,)
# (270, 4)

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,random_state=42, train_size=0.7)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (189, 4)
# (81, 4)
# (189,)
# (81,)

# %% [markdown]
# ### Building decision tree
# Use all default parameters except depth to build a simple tree

# %%
from sklearn.tree import DecisionTreeClassifier
import sklearn
sklearn.set_config(print_changed_only=False)

# %%
dt=DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
#Snippet to take your decision tree graph into an object and make an image from it.

#Libraries to plot the decision tree graph

from IPython.display import Image    #For any given structure you can draw an image
from six import StringIO
from sklearn.tree import export_graphviz  #graphviz object is what we plot as a graph.
import pydotplus, graphviz

# %%
#Steps to plot a decision tree graph

#1. Instantiate a string dot data file
dot_data=StringIO()

#2. Create a graphviz object and put it into the dot file
export_graphviz(dt, out_file=dot_data, filled=True, rounded=True, feature_names=X.columns, 
               class_names=['No Disease', 'Disease'])

#Using the graphviz object, want to create a graph
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# ## `Using plot_tree`

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(60,30))
plot_tree(dt, feature_names = X.columns,class_names=['No Disease', "Disease"],filled=True)
plt.show()

# %% [markdown]
# ## `Evaluate the model with train and test set`

# %%
y_train_pred=dt.predict(X_train)
y_test_pred=dt.predict(X_test)

# %%
#Metrics to check effectiveness
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

print('Train evaluation')
print(accuracy_score(y_train, y_train_pred))
print(confusion_matrix(y_train, y_train_pred))

print('-----------------------------------------------')
print('Test evaluation')
print(accuracy_score(y_test, y_test_pred))
print(confusion_matrix(y_test, y_test_pred))
# Out:
# Train evaluation
# 0.7407407407407407
# [[82 19]
#  [30 58]]
# -----------------------------------------------
# Test evaluation
# 0.6049382716049383
# [[35 14]
#  [18 14]]

# %% [markdown]
# `Since Hyper parameter tuning in Decision Tress is done with trial and error to avoid overfitting, creating functions that will perform the above atsks of creating graphs and evaluating models`

# %%
#Function to plot a decision tree

def get_dt_graph(dt_classifier):
    #1. Instantiate a string dot data file
    dot_data=StringIO()

    #2. Create a graphviz object and put it into the dot file
    export_graphviz(dt_classifier, out_file=dot_data, filled=True, rounded=True, feature_names=X.columns, 
                   class_names=['No Disease', 'Disease'])

    #Using the graphviz object, want to create a graph
    graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
    return graph

# %%
#Function to evaluate a model

def eval_model(dt_classifier):
    y_train_pred=dt_classifier.predict(X_train)
    y_test_pred=dt_classifier.predict(X_test)
    
    print('Train evaluation')
    print(accuracy_score(y_train, y_train_pred))
    print(confusion_matrix(y_train, y_train_pred))

    print('-----------------------------------------------')
    print('Test evaluation')
    print(accuracy_score(y_test, y_test_pred))
    print(confusion_matrix(y_test, y_test_pred))

# %%
graph= get_dt_graph(dt)
Image(graph.create_png())

# %%
eval_model(dt)
# Out:
# Train evaluation
# 0.7407407407407407
# [[82 19]
#  [30 58]]
# -----------------------------------------------
# Test evaluation
# 0.6049382716049383
# [[35 14]
#  [18 14]]

# %% [markdown]
# `Let's try to make a decision tree without any hyper parameter- completely default.(The first DT had a hyperparameter num of depths)`

# %%
default_dt=DecisionTreeClassifier(random_state=42)
default_dt.fit(X_train, y_train)

graph2=get_dt_graph(default_dt)
Image(graph2.create_png())

# %%
eval_model(default_dt)
# Out:
# Train evaluation
# 1.0
# [[101   0]
#  [  0  88]]
# -----------------------------------------------
# Test evaluation
# 0.6296296296296297
# [[31 18]
#  [12 20]]

# %% [markdown]
# `Controlling the depth of the DT`

# %%
dt2=DecisionTreeClassifier(max_depth=3, random_state=42)
dt2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
graph=get_dt_graph(dt2)
Image(graph.create_png())

# %%
eval_model(dt2)
# Out:
# Train evaluation
# 0.7407407407407407
# [[82 19]
#  [30 58]]
# -----------------------------------------------
# Test evaluation
# 0.6049382716049383
# [[35 14]
#  [18 14]]

# %% [markdown]
# `Specifying minimum number of samples before split in an internal node`

# %%
dt3=DecisionTreeClassifier(min_samples_split=20, random_state=42)
dt3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=20,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
graph=get_dt_graph(dt3)
Image(graph.create_png())

# %%
eval_model(dt3)
# Out:
# Train evaluation
# 0.8359788359788359
# [[85 16]
#  [15 73]]
# -----------------------------------------------
# Test evaluation
# 0.6419753086419753
# [[32 17]
#  [12 20]]

# %% [markdown]
# `Specifying minimum number of samples in a leaf node`

# %%
dt4=DecisionTreeClassifier(min_samples_leaf=20, random_state=42)
dt4.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=20, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
graph=get_dt_graph(dt4)
Image(graph.create_png())

# %%
eval_model(dt4)
# Out:
# Train evaluation
# 0.7037037037037037
# [[85 16]
#  [40 48]]
# -----------------------------------------------
# Test evaluation
# 0.6419753086419753
# [[38 11]
#  [18 14]]

# %% [markdown]
# `Using Entropy instead of Gini Index`

# %%
dt5=DecisionTreeClassifier(min_samples_leaf=20, random_state=42, criterion='entropy')
dt5.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=20, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
graph=get_dt_graph(dt5)
Image(graph.create_png())

# %%
eval_model(dt5)
# Out:
# Train evaluation
# 0.7037037037037037
# [[85 16]
#  [40 48]]
# -----------------------------------------------
# Test evaluation
# 0.6419753086419753
# [[38 11]
#  [18 14]]

# %% [markdown]
# # `Hyperparameter Tuning using GridsearchCv`

# %%
from sklearn.model_selection import GridSearchCV

# %%
dt6=DecisionTreeClassifier(random_state=42)

# %%
params={
    'max_leaf_nodes': [5,6,7,8,9,10,15,20,30,50,100],
    'max_depth': [3,4,5,7,10,15,20],
    'criterion' : ['gini', 'entropy']
    }

# %%
grid_search=GridSearchCV(estimator=dt6,
            param_grid=params,
            n_jobs=-1,
            verbose=1,
            scoring='accuracy'
            )

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 154 candidates, totalling 770 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 620 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 770 out of 770 | elapsed:    3.8s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=42,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 7, 10, 15, 20],
#                          'max_leaf_nodes': [5, 6, 7, 8, 9, 10, 15, 20, 30, 50,
#                                             100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=1)

# %%
dt_best=grid_search.best_estimator_
dt_best
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=None, max_leaf_nodes=6,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
eval_model(dt_best)
# Out:
# Train evaluation
# 0.7248677248677249
# [[85 16]
#  [36 52]]
# -----------------------------------------------
# Test evaluation
# 0.6296296296296297
# [[37 12]
#  [18 14]]

# %%
grid_result=pd.DataFrame(grid_search.cv_results_)
grid_result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.008036      0.001074         0.003989        0.000631
# 1       0.009701      0.000543         0.004753        0.000518
# 2       0.009794      0.001586         0.004968        0.000913
# 3       0.008177      0.001716         0.004058        0.000713
# 4       0.006815      0.000465         0.004536        0.001224
#
#   param_criterion param_max_depth param_max_leaf_nodes  \
# 0            gini               3                    5
# 1            gini               3                    6
# 2            gini               3                    7
# 3            gini               3                    8
# 4            gini               3                    9
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': 3, 'max_lea...           0.684211
# 1  {'criterion': 'gini', 'max_depth': 3, 'max_lea...           0.684211
# 2  {'criterion': 'gini', 'max_depth': 3, 'max_lea...           0.657895
# 3  {'criterion': 'gini', 'max_depth': 3, 'max_lea...           0.657895
# 4  {'criterion': 'gini', 'max_depth': 3, 'max_lea...           0.657895
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.710526           0.684211           0.631579           0.702703
# 1           0.710526           0.684211           0.605263           0.702703
# 2           0.710526           0.684211           0.605263           0.675676
# 3           0.710526           0.684211           0.605263           0.675676
# 4           0.710526           0.684211           0.605263           0.675676
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.682646        0.027540               31
# 1         0.677383        0.037508               46
# 2         0.666714        0.035100               66
# 3         0.666714        0.035100               66
# 4         0.666714        0.035100               66

# %%
grid_result=grid_result.sort_values(by='mean_test_score', ascending=False)
grid_result.head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 67       0.006771      0.001171         0.004388        0.001492
# 45       0.007196      0.001926         0.004381        0.000511
# 23       0.008589      0.001856         0.004790        0.000747
# 34       0.009375      0.000797         0.005584        0.000487
# 12       0.008336      0.001057         0.004794        0.000740
#
#    param_criterion param_max_depth param_max_leaf_nodes  \
# 67            gini              20                    6
# 45            gini              10                    6
# 23            gini               5                    6
# 34            gini               7                    6
# 12            gini               4                    6
#
#                                                params  split0_test_score  \
# 67  {'criterion': 'gini', 'max_depth': 20, 'max_le...           0.684211
# 45  {'criterion': 'gini', 'max_depth': 10, 'max_le...           0.684211
# 23  {'criterion': 'gini', 'max_depth': 5, 'max_lea...           0.684211
# 34  {'criterion': 'gini', 'max_depth': 7, 'max_lea...           0.684211
# 12  {'criterion': 'gini', 'max_depth': 4, 'max_lea...           0.684211
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 67           0.710526           0.710526           0.657895
# 45           0.710526           0.710526           0.657895
# 23           0.710526           0.710526           0.657895
# 34           0.710526           0.710526           0.657895
# 12           0.710526           0.710526           0.657895
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 67            0.72973         0.698578         0.02497                1
# 45            0.72973         0.698578         0.02497                1
# 23            0.72973         0.698578         0.02497                1
# 34            0.72973         0.698578         0.02497                1
# 12            0.72973         0.698578         0.02497                1

# %%
graph=get_dt_graph(dt_best)
Image(graph.create_png())
