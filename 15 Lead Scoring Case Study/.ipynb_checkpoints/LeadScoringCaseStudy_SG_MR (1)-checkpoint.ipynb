# %% [markdown]
# # Import

# %%
#Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

#Importing Libraries for splitting data into train and test
from sklearn.model_selection import train_test_split 

#Importing library for rescaling features:
from sklearn.preprocessing import StandardScaler

# %%
#Reading the datasets

leads = pd.read_csv('Leads.csv')
leads.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %% [markdown]
# # 1. Data Inspection and Data Cleaning.

# %% [markdown]
# ## 1.1 Data Analysis.

# %%
#Checking the spread of our target variable
leads.Converted.value_counts()
# Out:
# 0    5679
# 1    3561
# Name: Converted, dtype: int64

# %% [markdown]
# #### The spread of target variable seems good for classification.

# %%
#Reading the basic stats of the dataset without any processing
leads.describe()
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
#shape of our data
leads.shape
# Out:
# (9240, 37)

# %%
#Datatype of each variables
leads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Prospect ID                                    9240 non-null   object
#  1   Lead Number                                    9240 non-null   int64
#  2   Lead Origin                                    9240 non-null   object
#  3   Lead Source                                    9204 non-null   object
#  4   Do Not Email                                   9240 non-null   object
#  5   Do Not Call                                    9240 non-null   object
#  6   Converted                                      9240 non-null   int64
#  7   TotalVisits                                    9103 non-null   float64
#  8   Total Time Spent on Website                    9240 non-null   int64
# ...

# %%
#Unique values of columns and their number

for i in leads.columns:
    print(i)
    print(leads[i].value_counts())
    print('_____________________________________')
# Out:
# Prospect ID
# 1de1f208-0561-4b10-9eee-8e0350525d0f    1
# 50ad2a94-bbd8-4a4a-8aed-f91b87336bdb    1
# f0ffec59-a250-4ff5-af9b-014d6aad1aff    1
# d2086ddd-4a7e-11e6-b61b-22000aa8e760    1
# 5c0838f4-987c-4b0b-8468-9ad0ebf647b1    1
#                                        ..
# a7005c82-4010-4604-a9a2-44dad06e29fb    1
# 798fe5c0-216e-4c8b-83e0-b45366e5e401    1
# eb699478-42b2-4c45-88fe-6c1416064c90    1
# aa5a7ddf-b20e-4e2e-a477-15227ca4e96a    1
# 36b2d11d-c550-4402-87a9-7d90c8c7271f    1
# Name: Prospect ID, Length: 9240, dtype: int64
# _____________________________________
# Lead Number
# 608255    1
# 596233    1
# 656682    1
# 592824    1
# 652580    1
#          ..
# 631489    1
# 600768    1
# 598556    1
# 616923    1
# 655360    1
# Name: Lead Number, Length: 9240, dtype: int64
# _____________________________________
# Lead Origin
# Landing Page Submission    4886
# API                        3580
# Lead Add Form               718
# Lead Import                  55
# ...

# %% [markdown]
# #### There are no duplicates in Prospect ID
# #### There are no duplicates in Lead number.
# #### All values of column 'Update me on Supply Chain Content', Get updates on DM Content', 'I agree to pay the amount through cheque', 'Magazine', 'Receive More Updates About Our Courses' has no.
#
# #### Hence dropping these 7 columns

# %%
leads=leads.drop(['Prospect ID', 'Lead Number',  'Update me on Supply Chain Content', 'Get updates on DM Content', 
                 'I agree to pay the amount through cheque', 'Magazine', 'Receive More Updates About Our Courses'], axis=1)
leads.shape
# Out:
# (9240, 30)

# %%
#Column 'Donot Call' has 2 values saying Yes. Observing its behaviour with target
print(leads[leads['Do Not Call']=='No'].Converted.value_counts())

leads[leads['Do Not Call']=='Yes'].Converted
# Out:
# 0    5679
# 1    3559
# Name: Converted, dtype: int64
# 619     1
# 4335    1
# Name: Converted, dtype: int64

# %% [markdown]
# #### 'Do Not Call' variable = 'Yes' has 2 datapoints with a 50% split of converted and not converted. But since only 2 datapoints are yes, the model will be highly biased towards no. Also the spread of conversion for 'Do Not Call' = 'No' is well defined.

# %%
# Analyzing Column 'What matters most to you in choosing a course'

#Spread of converted and not converted for 'Better Career Prospects' in the column
print('Spread of converted and not converted for Better Career Prospects')
print(leads[leads['What matters most to you in choosing a course']=='Better Career Prospects'].Converted.value_counts())

#Column 'What matters most to you in choosing a course' has 2 values saying with 2 and 1 rows respectively. Observing its behaviour with taget
print(leads[leads['What matters most to you in choosing a course']=='Flexibility & Convenience'].Converted)
print(leads[leads['What matters most to you in choosing a course']=='Other'].Converted)
# Out:
# Spread of converted and not converted for Better Career Prospects
# 0    3338
# 1    3190
# Name: Converted, dtype: int64
# 3064    0
# 4550    1
# Name: Converted, dtype: int64
# 8251    0
# Name: Converted, dtype: int64

# %% [markdown]
# #### Since the column 'What matters most to you in choosing a course' has 2 values with 'Flexibility & Convenience' and 'Other' with only 3 rows in total. Also the spread of conversion for 'What matters most to you in choosing a course' = 'Better Career Prospects' is well defined.

# %% [markdown]
# ## 1.2 Null Value Treatment

# %% [markdown]
# #### We can observe null values on the columns.
# #### Dropiing columns with a huge number of missing value and if the column is very important taking a call to treat them.

# %%
ln = leads.isnull().sum() * 100/len(leads)
ln[ln > 0]
# Out:
# Lead Source                                       0.389610
# TotalVisits                                       1.482684
# Page Views Per Visit                              1.482684
# Last Activity                                     1.114719
# Country                                          26.634199
# Specialization                                   15.562771
# How did you hear about X Education               23.885281
# What is your current occupation                  29.112554
# What matters most to you in choosing a course    29.318182
# Tags                                             36.287879
# Lead Quality                                     51.590909
# Lead Profile                                     29.318182
# City                                             15.367965
# Asymmetrique Activity Index                      45.649351
# Asymmetrique Profile Index                       45.649351
# Asymmetrique Activity Score                      45.649351
# ...

# %%
#dropping columns with high percentage of nulls > 40%             
leads.drop(ln[ln>40].index, axis = 1, inplace = True)

# %%
leads.shape
# Out:
# (9240, 25)

# %% [markdown]
# #### After dropping columns with null values > 40%, treating rest of the columns with smaller counts null values.

# %%
#Substitute a generic 'Not Specified' value for null
leads['Lead Source'].fillna("Not Specified", inplace = True)

# %%
#Since the mode and least number of total visits possible is 0, replacing null values of total visits by 0.
leads['TotalVisits'].fillna(0, inplace = True)

# %%
#Since the mode and least number of Page Views Per Visit possible is 0, replacing null values of total visits by 0.
leads['Page Views Per Visit'].fillna(0, inplace = True)

# %%
#Substitute a generic 'Not Specified' value for null
leads['Last Activity'].fillna("Not Specified", inplace = True)

# %%
#Analyzing Country.

#Since India constitutes most of the spread of the datapoints, analyzing if all the conversions are from India or other
#countries have conversion too.
leads[leads['Country']=='India'].Converted.value_counts()
# Out:
# 0    4091
# 1    2401
# Name: Converted, dtype: int64

# %%
#Substituting Not Specified instead of missing values in Country column
leads['Country'].fillna("Not Specified", inplace = True)

# %%
#Select seems to be the default value when a 'Specialization','How did you hear about X Education','Lead Profile','City'
# is not selected.
select_default_value = ['Specialization','How did you hear about X Education','Lead Profile','City']
for i in select_default_value:
    default_null= len(leads[leads[i]=='Select']) * 100/len(leads)
    print(i, default_null)
# Out:
# Specialization 21.017316017316016
# How did you hear about X Education 54.577922077922075
# Lead Profile 44.87012987012987
# City 24.33982683982684

# %% [markdown]
# #### Dropiing columns 'How did you hear about X Education' and 'Lead Profile' since they have an highest imbalance with 'Select' which is as good as null values- There is nothing specified for them.

# %%
leads=leads.drop(['How did you hear about X Education', 'Lead Profile' ], axis=1)

# %%
# Replacing value=Select from columns Specialization and City with our analysis default 'not Specified'
leads[['Specialization', 'City']]=leads[['Specialization', 'City']].replace(['Select'], 'Not Specified')

# %%
leads.shape
# Out:
# (9240, 23)

# %% [markdown]
# ### 1.3 Identifying outliers and treating them.

# %%
#Getting the numerical and categorical columns
num_col = leads.select_dtypes(include=np.number).columns

cat_col = leads.select_dtypes(include=np.object).columns
(num_col,cat_col)
# Out:
# (Index(['Converted', 'TotalVisits', 'Total Time Spent on Website',
#         'Page Views Per Visit'],
#        dtype='object'),
#  Index(['Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call',
#         'Last Activity', 'Country', 'Specialization',
#         'What is your current occupation',
#         'What matters most to you in choosing a course', 'Search',
#         'Newspaper Article', 'X Education Forums', 'Newspaper',
#         'Digital Advertisement', 'Through Recommendations', 'Tags', 'City',
#         'A free copy of Mastering The Interview', 'Last Notable Activity'],
#        dtype='object'))

# %%
# Checking outliers for numerical columns excluding the target using boxplots:
plt.figure(figsize = (16,8))
subplot = 221
for i in leads[num_col.drop('Converted')]:
    plt.subplot(subplot)
    sns.boxplot(leads[i])
    subplot +=1
plt.tight_layout()

# %% [markdown]
# #### Based on the boxplots and describe function on the dataset:
# 1. The average Total Visits by a prospect customer and lead procurred was 3, minimum was 0 and 75% was 5 while the maximum Total Visits is 251 which is clearly an outlier. Also there are other outliers which are clearly visible from the boxplots.
# 2. There are no visible outliers for Total Time Spend on Website. Need to analyze more on that.
# 3. The average Page Views Per Visit by a prospect customer and lead procurred was 2, minimum was 0 and 75% was 3 while the maximum Page Views Per Visit is 55 which is clearly an outlier. Also there are other outliers which are clearly visible from the boxplots.

# %%
def num_outliers(dataframe):
    q1=dataframe.quantile(0.25)
    q3=dataframe.quantile(0.75)
    iqr=q3-q1
    outlier=((dataframe < (q1 - 1.5 * iqr)) | (dataframe > (q3 + 1.5 * iqr))).sum()
    print('q1')
    print(q1)
    print('\nq3')
    print(q3)
    print('\nIQR ')
    print(iqr)
    print('\nNumber of outliers')
    return outlier
outlier=num_outliers(leads[num_col.drop('Converted')])
outlier
# Out:
# q1
# TotalVisits                     0.0
# Total Time Spent on Website    12.0
# Page Views Per Visit            0.0
# Name: 0.25, dtype: float64
#
# q3
# TotalVisits                      5.0
# Total Time Spent on Website    936.0
# Page Views Per Visit             3.0
# Name: 0.75, dtype: float64
#
# IQR
# TotalVisits                      5.0
# Total Time Spent on Website    924.0
# Page Views Per Visit             3.0
# dtype: float64
#
# Number of outliers
# TotalVisits                    222
# Total Time Spent on Website      0
# Page Views Per Visit           209
# dtype: int64

# %% [markdown]
# #### Statistically there are no outliers on Total Time Spent on Website.
# #### Based on experience for columns TotalVisits and Page Views Per Visit, values > 1.5 * IQR might not serve as the perfect outliers that requires treatment.
# #### For TotalVisits value>30  and for Page Views Per Visit > 15 can serve as  <font color='red'>major outliers.</font>
# Further analyzing the value counts for these outliers

# %%
#Checking number of datapoints with our assumed outliers along with our target variable distribution.
print(leads[leads['TotalVisits'] > 30].Converted.value_counts())
print(leads[leads['Page Views Per Visit'] > 15].Converted.value_counts())
# Out:
# 0    9
# 1    1
# Name: Converted, dtype: int64
# 0    4
# 1    1
# Name: Converted, dtype: int64

# %%
#Outlier treatment
leads['TotalVisits']=leads['TotalVisits'].apply(lambda x: 30 if x>30 else x)
leads['Page Views Per Visit']=leads['Page Views Per Visit'].apply(lambda x: 15 if x>15 else x)

# %%
leads.shape
# Out:
# (9240, 23)

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ## 2.1 Univariate Analysis

# %% [markdown]
# #### Univariate analysis for numerical variables.

# %%
plt.figure(figsize=(16,14))
bar_pos=0
for i in range(0, 3):
    plt.subplot(2,2,i+1)
    sns.distplot(leads[num_col.drop('Converted')[i]])
    bar_pos=i+1
plt.subplot(2,2,bar_pos+1)
leads['Converted'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Insights:
# - Total Visit data is positively skewed. Most of our data has a Total Visit between 0-4.
# - Total Time spent on website is positively skewed as well. Most of our data spends a total time from 0-400 units.
# - Again Page views per visit is positively skewed. The average Page views per visit is 2.36 units and m ost of our data lies in the range of 0-3.
# - The spread of target variable seems good for classification.

# %% [markdown]
# ## 2.2 Bivariate and Multivariate analysis

# %% [markdown]
# #### Bivariate and Univariate analysis for categorical variables together.

# %%
for column in cat_col:
    plt.figure(figsize=(30,6))
    plt.subplot(121)
    sns.countplot(x=leads[column],hue=leads['Converted'],data=leads)
    plt.title(column)    
    plt.xticks(rotation=90)

# %% [markdown]
# ## Insights:
# - Lead Origin has been highest with Landing Page Submission both for converted and non-converted categories followed by API. The ratio of non conversion to conversion is greater than 1. In case of Lead Add Form, the number of Lead Origin is less but the ratio of non conversion to conversion is less than 1 which is a ggod scenario. Similar case is with Lead Import but here the overall count ius very less.
# - The best lead sources were Direct traffics and Google where the better ratio of non conversion to conversion is given by Google. Good lead sources(less than the best) are Olark Chat, organic chat and through references. In these cases Olark chat and organic search has a positive non conversion to conversion but lead soiurces through references have the best non conversion to conversion ratio(negative).
# - Number of datapoints, who donot want emails are huge compared to those who want. Conversion rate for those who don't want are better.
# - People who wants to be called are negligible. Hence will be dropping this variable.
# -

# %%
leads=leads.drop(['Do Not Call', 'Newspaper', 'Newspaper Article', 'X Education Forums', 'Digital Advertisement', 
           'Through Recommendations', 'What matters most to you in choosing a course', 'Search', 'Country'], axis=1)
leads.shape
# Out:
# (9240, 14)

# %% [markdown]
# #### Bivariate analysis for numerical variables.

# %%
#Pairplots to visualize the correlation between the numerical variables
sns.pairplot(leads)
plt.show()

# %%
#Visualizing correlation between the numerical variables with correlation matrix using heatmaps.
sns.heatmap(leads[num_col].corr(), annot=True, vmin=-1, vmax=1, center= 0)
plt.show()

# %% [markdown]
# ## Insights:

# %% [markdown]
# # 3. Data Preparation.

# %% [markdown]
# ## 3.1 Dummy variable creation

# %%
pd.set_option('display.max_columns', None)
leads.head()
# Out:
#                Lead Origin     Lead Source Do Not Email  Converted  \
# 0                      API      Olark Chat           No          0
# 1                      API  Organic Search           No          0
# 2  Landing Page Submission  Direct Traffic           No          1
# 3  Landing Page Submission  Direct Traffic           No          0
# 4  Landing Page Submission          Google           No          1
#
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#              Last Activity           Specialization  \
# 0  Page Visited on Website            Not Specified
# 1             Email Opened            Not Specified
# ...

# %%
#Keeping the dataframe leads as the one without any binary mapping or dummy variables

leads_computed = leads.copy()

# Converting the binary variables (Yes/No) to 0/1

# List of variables to map
varlist =  ['Do Not Email', 'A free copy of Mastering The Interview']

# Defining the map function
def binary_map(x):
    return x.map({'Yes': 1, "No": 0})

# Applying the function to the leads list
leads_computed[varlist] = leads_computed[varlist].apply(binary_map)

# %%
leads_computed.head()
# Out:
#                Lead Origin     Lead Source  Do Not Email  Converted  \
# 0                      API      Olark Chat             0          0
# 1                      API  Organic Search             0          0
# 2  Landing Page Submission  Direct Traffic             0          1
# 3  Landing Page Submission  Direct Traffic             0          0
# 4  Landing Page Submission          Google             0          1
#
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#              Last Activity           Specialization  \
# 0  Page Visited on Website            Not Specified
# ...

# %%
leads_computed.columns
# Out:
# Index(['Lead Origin', 'Lead Source', 'Do Not Email', 'Converted',
#        'TotalVisits', 'Total Time Spent on Website', 'Page Views Per Visit',
#        'Last Activity', 'Specialization', 'What is your current occupation',
#        'Tags', 'City', 'A free copy of Mastering The Interview',
#        'Last Notable Activity'],
#       dtype='object')

# %%
#Creating Dummy Variables.

# Creating dummy variables for the variable 'Lead Origin'
ml = pd.get_dummies(leads_computed['Lead Origin'], prefix='Lead Origin')
# Dropping MultipleLines_No phone service column
ml1 = ml.drop(['Lead Origin_Quick Add Form'], 1)
#Adding the results to the master dataframe
leads_computed = pd.concat([leads_computed,ml1], axis=1)

# Creating dummy variables for the variable 'Lead Source'
ml = pd.get_dummies(leads_computed['Lead Source'], prefix='Lead Source')
# Dropping MultipleLines_No phone service column
ml1 = ml.drop(['Lead Source_NC_EDM'], 1)
#Adding the results to the master dataframe
leads_computed = pd.concat([leads_computed,ml1], axis=1)

# Creating dummy variables for the variable 'Last Activity'
ml = pd.get_dummies(leads_computed['Last Activity'], prefix='Last Activity')
# Dropping MultipleLines_No phone service column
ml1 = ml.drop(['Last Activity_Resubscribed to emails'], 1)
#Adding the results to the master dataframe
leads_computed = pd.concat([leads_computed,ml1], axis=1)

# # Creating dummy variables for the variable 'Country'
# ml = pd.get_dummies(leads_computed['Country'], prefix='Country')
# # Dropping MultipleLines_No phone service column
# ml1 = ml.drop(['Country_Indonesia'], 1)
# #Adding the results to the master dataframe
# leads_computed = pd.concat([leads_computed,ml1], axis=1)

# Creating dummy variables for the variable 'Specialization'
ml = pd.get_dummies(leads_computed['Specialization'], prefix='Specialization')
# Dropping MultipleLines_No phone service column
ml1 = ml.drop(['Specialization_E-Business'], 1)
#Adding the results to the master dataframe
leads_computed = pd.concat([leads_computed,ml1], axis=1)

# Creating dummy variables for the variable 'What is your current occupation'
ml = pd.get_dummies(leads_computed['What is your current occupation'], prefix='What is your current occupation')
# Dropping MultipleLines_No phone service column
ml1 = ml.drop(['What is your current occupation_Housewife'], 1)
#Adding the results to the master dataframe
leads_computed = pd.concat([leads_computed,ml1], axis=1)


# Creating dummy variables for the variable 'Tags'
ml = pd.get_dummies(leads_computed['Tags'], prefix='Tags')
# Dropping MultipleLines_No phone service column
ml1 = ml.drop(['Tags_University not recognized'], 1)
#Adding the results to the master dataframe
leads_computed = pd.concat([leads_computed,ml1], axis=1)

# Creating dummy variables for the variable 'City'
ml = pd.get_dummies(leads_computed['City'], prefix='City')
# Dropping MultipleLines_No phone service column
ml1 = ml.drop(['City_Tier II Cities'], 1)
#Adding the results to the master dataframe
leads_computed = pd.concat([leads_computed,ml1], axis=1)

# Creating dummy variables for the variable 'Last Notable Activity'
ml = pd.get_dummies(leads_computed['Last Notable Activity'], prefix='Last Notable Activity')
# Dropping MultipleLines_No phone service column
ml1 = ml.drop(['Last Notable Activity_Email Marked Spam'], 1)
#Adding the results to the master dataframe
leads_computed = pd.concat([leads_computed,ml1], axis=1)

# %%
#Dropping the columns for which dummy variables are created.

leads_computed=leads_computed.drop(['Lead Origin', 'Lead Source', 'Last Activity', 'Specialization', 'What is your current occupation',
                    'Tags', 'City', 'Last Notable Activity'], axis=1)
leads_computed.head()
# Out:
#    Do Not Email  Converted  TotalVisits  Total Time Spent on Website  \
# 0             0          0          0.0                            0
# 1             0          0          5.0                          674
# 2             0          1          2.0                         1532
# 3             0          0          1.0                          305
# 4             0          1          2.0                         1428
#
#    Page Views Per Visit  A free copy of Mastering The Interview  \
# 0                   0.0                                       0
# 1                   2.5                                       0
# 2                   2.0                                       1
# 3                   1.0                                       0
# 4                   1.0                                       0
#
#    Lead Origin_API  Lead Origin_Landing Page Submission  \
# 0                1                                    0
# ...

# %%
leads_computed.shape
# Out:
# (9240, 117)

# %% [markdown]
# ## 3.2 Train test split

# %%
# Splitting data into X and y
X=leads_computed.drop('Converted', axis=1)
y=leads_computed['Converted']
print(X.shape, y.shape)

# Splitting X and y into training and test datasets
X_train, X_test, y_train, y_test= train_test_split(X, y, random_state=100, train_size=0.7)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (9240, 116) (9240,)
# (6468, 116) (6468,)
# (2772, 116) (2772,)

# %% [markdown]
# ## 3.3 Rescaling the variables

# %%
scaler=StandardScaler()

X_train[num_col.drop('Converted')]=scaler.fit_transform(X_train[num_col.drop('Converted')])
X_train.head()
# Out:
#       Do Not Email  TotalVisits  Total Time Spent on Website  \
# 1871             0    -0.932250                    -0.885371
# 6795             0     0.183345                     0.005716
# 3516             0     0.462244                    -0.691418
# 8105             0     0.462244                     1.365219
# 3934             0    -0.932250                    -0.885371
#
#       Page Views Per Visit  A free copy of Mastering The Interview  \
# 1871             -1.113301                                       0
# 6795             -0.472142                                       1
# 3516              0.091886                                       0
# 8105              1.297073                                       0
# 3934             -1.113301                                       0
#
#       Lead Origin_API  Lead Origin_Landing Page Submission  \
# 1871                1                                    0
# 6795                0                                    1
# ...

# %% [markdown]
# # 4. Model
